# %% [markdown]
# <a href="https://colab.research.google.com/github/SadeemAlasiri/Ex_week3/blob/main/Copy_of_Hierarchical_Clustering_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Python Implementation using the scikit-learn library**

# %% [markdown]
# #Step 1 : import libraries

# %%
import numpy as np # ناديت المكتبات
from scipy.cluster.hierarchy import dendrogram ,linkage # هذه للربط
import matplotlib.pyplot as plt# هذه للرسم

# %% [markdown]
# #Step 2 : Randomly chosen dataset

# %%
X=np.array([
    [1,3],[4,5],[5,7],[5,9],[10,12],
     [13,14],[15,17],[18,19],[20,21]])# الداتا حقتي

# %%
X
# Out:
# array([[ 1,  3],
#        [ 4,  5],
#        [ 5,  7],
#        [ 5,  9],
#        [10, 12],
#        [13, 14],
#        [15, 17],
#        [18, 19],
#        [20, 21]])

# %% [markdown]
# #Step 3 : Perform hierarchical clustering  + Ploting

# %%
plt.scatter(X[:,0],X[:,1])

# %%
H=linkage(X,'ward')# هذه تقوم بقراتها وحساب المسافه

dendrogram(H);# الرسمه
